# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd  /gdrive/MyDrive/364/'Logistic Regression Comp'/
# %ls
# Out:
# /gdrive/MyDrive/364/Logistic Regression Comp
#  Exploration.ipynb  'Model Testing and Selection.ipynb'   __pycache__/
#  LogReg-data.csv     processing.py                        test.ipynb

# %%
df = pd.read_csv('LogReg-data.csv')
df # data has many different scales, should standardize / normalize the variables
# Out:
#         A1    A2   A3    A4    A5    A6    A7     A8       A9   A10    A11  y
# 0      8.8  0.45  7.0  3.00  45.0  0.36  0.27  0.045  1.00100  20.7  170.0  0
# 1      9.5  0.49  6.3  3.30  14.0  0.34  0.30  0.049  0.99400   1.6  132.0  0
# 2     10.1  0.44  8.1  3.26  30.0  0.40  0.28  0.050  0.99510   6.9   97.0  0
# 3      9.9  0.40  7.2  3.19  47.0  0.32  0.23  0.058  0.99560   8.5  186.0  0
# 4      9.9  0.40  7.2  3.19  47.0  0.32  0.23  0.058  0.99560   8.5  186.0  0
# ...    ...   ...  ...   ...   ...   ...   ...    ...      ...   ...    ... ..
# 3150   8.9  0.46  5.7  3.22  41.0  0.20  0.22  0.044  0.99862  16.0  113.0  0
# 3151  10.1  0.50  5.7  3.30  23.0  0.24  0.26  0.059  0.99773  17.8  124.0  1
# 3152  10.1  0.50  5.7  3.30  23.0  0.24  0.26  0.059  0.99773  17.8  124.0  1
# 3153  11.0  0.42  6.0  3.15  22.0  0.26  0.20  0.049  0.99280   6.8   93.0  0
# 3154  11.0  0.42  6.0  3.15  22.0  0.26  0.20  0.049  0.99280   6.8   93.0  0
#
# [3155 rows x 12 columns]

# %% [markdown]
# # Exploration

# %%
df.head(20)
# Out:
#       A1    A2   A3    A4    A5    A6    A7     A8      A9    A10    A11  y
# 0    8.8  0.45  7.0  3.00  45.0  0.36  0.27  0.045  1.0010  20.70  170.0  0
# 1    9.5  0.49  6.3  3.30  14.0  0.34  0.30  0.049  0.9940   1.60  132.0  0
# 2   10.1  0.44  8.1  3.26  30.0  0.40  0.28  0.050  0.9951   6.90   97.0  0
# 3    9.9  0.40  7.2  3.19  47.0  0.32  0.23  0.058  0.9956   8.50  186.0  0
# 4    9.9  0.40  7.2  3.19  47.0  0.32  0.23  0.058  0.9956   8.50  186.0  0
# 5   10.1  0.44  8.1  3.26  30.0  0.40  0.28  0.050  0.9951   6.90   97.0  0
# 6    9.6  0.47  6.2  3.18  30.0  0.16  0.32  0.045  0.9949   7.00  136.0  0
# 7    8.8  0.45  7.0  3.00  45.0  0.36  0.27  0.045  1.0010  20.70  170.0  0
# 8    9.5  0.49  6.3  3.30  14.0  0.34  0.30  0.049  0.9940   1.60  132.0  0
# 9   11.0  0.45  8.1  3.22  28.0  0.43  0.22  0.044  0.9938   1.50  129.0  0
# 10  12.0  0.56  8.1  2.99  11.0  0.41  0.27  0.033  0.9908   1.45   63.0  1
# 11   9.7  0.53  8.6  3.14  17.0  0.40  0.23  0.035  0.9947   4.20  109.0  1
# 12  10.8  0.63  7.9  3.18  16.0  0.37  0.18  0.040  0.9920   1.20   75.0  1
# 13   9.7  0.67  8.3  2.98  41.0  0.62  0.42  0.040  1.0002  19.25  172.0  1
# 14   9.6  0.36  6.3  3.24  30.0  0.04  0.48  0.046  0.9928   1.10   99.0  0
# 15  11.3  0.53  7.4  3.12  17.0  0.42  0.34  0.033  0.9917   1.10  171.0  0
# 16   9.5  0.50  6.5  3.22  34.0  0.14  0.31  0.044  0.9955   7.50  133.0  1
# 17   9.3  0.51  7.6  3.05  25.0  0.14  0.67  0.074  0.9937   1.50  168.0  1
# 18  10.0  0.47  6.6  3.42  16.0  0.41  0.27  0.052  0.9951   1.30  142.0  0
# 19  10.4  0.50  7.0  3.25  56.0  0.32  0.25  0.046  0.9955   9.00  245.0  0

# %%
df.shape
# Out:
# (3155, 12)

# %%
df.describe()
# Out:
#                 A1           A2           A3           A4           A5  \
# count  3155.000000  3155.000000  3155.000000  3155.000000  3155.000000
# mean     10.202948     0.486510     6.956165     3.180983    36.193819
# std       1.071792     0.107863     0.835112     0.148413    16.912455
# min       8.000000     0.230000     3.800000     2.720000     2.000000
# 25%       9.400000     0.410000     6.400000     3.080000    24.000000
# 50%      10.000000     0.470000     6.900000     3.170000    35.000000
# 75%      10.900000     0.540000     7.400000     3.270000    48.000000
# max      14.000000     1.060000    14.200000     3.810000   131.000000
#
#                 A6           A7           A8           A9          A10  \
# count  3155.000000  3155.000000  3155.000000  3155.000000  3155.000000
# mean      0.342273     0.274669     0.047818     0.994646     6.845975
# std       0.129811     0.094539     0.022959     0.002904     5.313763
# min       0.000000     0.080000     0.009000     0.987220     0.600000
# 25%       0.260000     0.210000     0.038000     0.992500     1.700000
# 50%       0.320000     0.260000     0.045000     0.994500     6.200000
# 75%       0.400000     0.320000     0.051000     0.996700    10.600000
# max       1.660000     0.965000     0.346000     1.038980    65.800000
#
#                A11            y
# count  3155.000000  3155.000000
# mean    144.295563     0.410143
# std      43.582818     0.491937
# min       9.000000     0.000000
# 25%     112.000000     0.000000
# 50%     143.000000     0.000000
# 75%     176.000000     1.000000
# max     344.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3155 entries, 0 to 3154
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A1      3155 non-null   float64
#  1   A2      3155 non-null   float64
#  2   A3      3155 non-null   float64
#  3   A4      3155 non-null   float64
#  4   A5      3155 non-null   float64
#  5   A6      3155 non-null   float64
#  6   A7      3155 non-null   float64
#  7   A8      3155 non-null   float64
#  8   A9      3155 non-null   float64
#  9   A10     3155 non-null   float64
#  10  A11     3155 non-null   float64
#  11  y       3155 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 295.9 KB

# %%
sns.pairplot(df, kind='reg')

# %%
# let's take a look at the percentage of zeros: 
df.isin([0]).sum()/df.shape[0]*100 

# only A6 has a small amount of zeros, the rest have none
# Out:
# A1      0.000000
# A2      0.000000
# A3      0.000000
# A4      0.000000
# A5      0.000000
# A6      0.285261
# A7      0.000000
# A8      0.000000
# A9      0.000000
# A10     0.000000
# A11     0.000000
# y      58.985737
# dtype: float64

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 12, 12


sns.heatmap(df.corr(), annot=True)

# %%
df.isnull().any()
# Out:
# A1     False
# A2     False
# A3     False
# A4     False
# A5     False
# A6     False
# A7     False
# A8     False
# A9     False
# A10    False
# A11    False
# y      False
# dtype: bool

# %%
df.describe()
# Out:
#                 A1           A2           A3           A4           A5  \
# count  3155.000000  3155.000000  3155.000000  3155.000000  3155.000000
# mean     10.202948     0.486510     6.956165     3.180983    36.193819
# std       1.071792     0.107863     0.835112     0.148413    16.912455
# min       8.000000     0.230000     3.800000     2.720000     2.000000
# 25%       9.400000     0.410000     6.400000     3.080000    24.000000
# 50%      10.000000     0.470000     6.900000     3.170000    35.000000
# 75%      10.900000     0.540000     7.400000     3.270000    48.000000
# max      14.000000     1.060000    14.200000     3.810000   131.000000
#
#                 A6           A7           A8           A9          A10  \
# count  3155.000000  3155.000000  3155.000000  3155.000000  3155.000000
# mean      0.342273     0.274669     0.047818     0.994646     6.845975
# std       0.129811     0.094539     0.022959     0.002904     5.313763
# min       0.000000     0.080000     0.009000     0.987220     0.600000
# 25%       0.260000     0.210000     0.038000     0.992500     1.700000
# 50%       0.320000     0.260000     0.045000     0.994500     6.200000
# 75%       0.400000     0.320000     0.051000     0.996700    10.600000
# max       1.660000     0.965000     0.346000     1.038980    65.800000
#
#                A11            y
# count  3155.000000  3155.000000
# mean    144.295563     0.410143
# std      43.582818     0.491937
# min       9.000000     0.000000
# 25%     112.000000     0.000000
# 50%     143.000000     0.000000
# 75%     176.000000     1.000000
# max     344.000000     1.000000

# %%
for col in df.columns:
  print(df[col].value_counts())
# Out:
# 9.5     191
# 9.4     187
# 9.2     180
# 9.0     134
# 10.0    130
# 10.4    113
# 9.3     113
# 10.5    107
# 9.1     100
# 9.8      99
# 9.6      99
# 10.2     97
# 9.9      93
# 10.6     91
# 10.8     90
# 10.1     89
# 11.0     84
# 9.7      83
# 8.8      80
# 8.9      76
# 11.4     76
# 10.3     64
# 8.7      61
# 10.7     56
# 11.2     56
# 11.3     51
# 12.0     51
# 10.9     46
# 11.5     44
# 12.2     43
# 12.5     39
# 11.1     39
# 11.7     31
# 11.8     28
# 12.3     26
# 12.4     25
# 11.6     25
# 11.9     22
# 12.1     21
# 12.6     19
# 12.7     19
# 8.6      16
# 12.8     13
# 12.9     13
# 13.0      8
# 8.5       7
# 13.2      4
# 13.4      4
# 13.6      4
# 13.1      2
# 8.4       2
# 8.0       1
# 14.0      1
# 13.5      1
# 13.3      1
# Name: A1, dtype: int64
# 0.50    174
# 0.46    149
# 0.42    138
# 0.38    135
# 0.44    134
#        ...
# 1.00      1
# 0.25      1
# 0.26      1
# 0.90      1
# 0.23      1
# Name: A2, Length: 67, dtype: int64
# 6.8    211
# 6.6    198
# 6.4    171
# 6.9    160
# 7.0    154
#       ...
# 9.9      1
# 4.6      1
# 4.5      1
# 4.7      1
# 3.8      1
# Name: A3, Length: 62, dtype: int64
# 3.14    115
# 3.16    103
# 3.22    101
# 3.19    100
# 3.20     98
#        ...
# 3.81      1
# 2.77      1
# 3.62      1
# 2.74      1
# 2.72      1
# Name: A4, Length: 96, dtype: int64
# 26.0     83
# 29.0     81
# 31.0     78
# 36.0     77
# 24.0     74
#          ..
# 96.0      1
# 128.0     1
# 110.0     1
# 42.5      1
# 23.5      1
# Name: A5, Length: 115, dtype: int64
# 0.30    181
# 0.49    160
# 0.28    159
# 0.32    148
# 0.34    145
#        ...
# 1.23      1
# 0.99      1
# 0.78      1
# 1.66      1
# 0.86      1
# Name: A6, Length: 84, dtype: int64
# 0.240    178
# 0.260    169
# 0.250    169
# 0.280    160
# 0.270    157
#         ...
# 0.905      1
# 0.135      1
# 0.225      1
# 0.395      1
# 0.650      1
# Name: A7, Length: 108, dtype: int64
# 0.044    139
# 0.046    136
# 0.040    133
# 0.045    129
# 0.042    128
#         ...
# 0.148      1
# 0.158      1
# 0.099      1
# 0.142      1
# 0.145      1
# Name: A8, Length: 141, dtype: int64
# 0.99280    50
# 0.99200    42
# 0.99320    41
# 0.99380    38
# 0.99540    37
#            ..
# 0.99632     1
# 0.99177     1
# 0.98923     1
# 0.99954     1
# 1.00120     1
# Name: A9, Length: 713, dtype: int64
# 1.40     117
# 1.20     114
# 1.60     106
# 1.50     102
# 1.30      94
#         ...
# 19.60      1
# 1.65       1
# 65.80      1
# 15.15      1
# 20.30      1
# Name: A10, Length: 275, dtype: int64
# 117.0    41
# 111.0    36
# 131.0    35
# 133.0    33
# 156.0    33
#          ..
# 232.0     1
# 217.5     1
# 48.0      1
# 62.0      1
# 176.5     1
# Name: A11, Length: 232, dtype: int64
# 0    1861
# 1    1294
# Name: y, dtype: int64
