# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# %cd  /gdrive/MyDrive/364/'Logistic Regression Comp'/
# %ls
# Out:
# /gdrive/MyDrive/364/Logistic Regression Comp
#  Exploration.ipynb            LogReg-TestingSubmission.py          __pycache__/
#  LogReg-data.csv              model.pickle                         test.ipynb
#  LogReg-sample-features.csv  'Model Testing and Selection.ipynb'
#  LogReg-sample-target.csv     process.py

# %%
import pickle
import numpy as np
from sklearn.metrics import confusion_matrix
from process import process

model = pickle.load(open("model.pickle", "rb"))

X = np.genfromtxt("LogReg-sample-features.csv", delimiter=",")
y = np.genfromtxt("LogReg-sample-target.csv")

y_pred = model.predict(process(X))

print(confusion_matrix(y, y_pred))
# Out:
# [[50 13]
#  [12 25]]
